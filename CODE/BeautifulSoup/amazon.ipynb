# %%
import requests 
from bs4 import BeautifulSoup 
import csv

# %%
from bs4 import BeautifulSoup
import requests

# Function to extract Product Title
def get_title(soup):
	
	try:
		# Outer Tag Object
		title = soup.find("span", attrs={"id":'productTitle'})

		# Inner NavigableString Object
		title_value = title.string

		# Title as a string value
		title_string = title_value.strip()

		# # Printing types of values for efficient understanding
		# print(type(title))
		# print(type(title_value))
		# print(type(title_string))
		# print()

	except AttributeError:
		title_string = ""	

	return title_string

# Function to extract Product Price
def get_price(soup):

	try:
		price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()

	except AttributeError:
		price = ""	

	return price

# Function to extract Product Rating
def get_rating(soup):

	try:
		rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
		
	except AttributeError:
		
		try:
			rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
		except:
			rating = ""	

	return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
	try:
		review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()
		
	except AttributeError:
		review_count = ""	

	return review_count

# Function to extract Availability Status
def get_availability(soup):
	try:
		available = soup.find("div", attrs={'id':'availability'})
		available = available.find("span").string.strip()

	except AttributeError:
		available = ""	

	return available	

if __name__ == '__main__':

	# Headers for request
	HEADERS = ({'User-Agent':
	            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
	            'Accept-Language': 'en-US, en;q=0.5'})

	# The webpage URL
	URL = "https://www.amazon.com/Sony-PlayStation-Pro-1TB-Console-4/dp/B07K14XKZH/"

	# HTTP Request
	webpage = requests.get(URL, headers=HEADERS)

	# Soup Object containing all data
	soup = BeautifulSoup(webpage.content, "lxml")

	# Function calls to display all necessary product information
	print("Product Title =", get_title(soup))
	print("Product Price =", get_price(soup))
	print("Product Rating =", get_rating(soup))
	print("Number of Product Reviews =", get_review_count(soup))
	print("Availability =", get_availability(soup))
	print()
	print()
# Out:
# Product Title = Sony PlayStation 4 Pro 1TB Console - Black (PS4 Pro)
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 4,218 ratings
# Availability = Only 1 left in stock - order soon.

# %%
from bs4 import BeautifulSoup
import requests

# Function to extract Product Title
def get_title(soup):
    try:
        title = soup.find("span", attrs={"id": 'productTitle'})
        title_value = title.string
        title_string = title_value.strip()
    except AttributeError:
        title_string = ""
    return title_string

# Function to extract Product Price
def get_price(soup):
    try:
        price = soup.find("span", attrs={'id': 'priceblock_ourprice'}).string.strip()
    except AttributeError:
        price = ""
    return price

# Function to extract Product Rating
def get_rating(soup):
    try:
        rating = soup.find("i", attrs={'class': 'a-icon a-icon-star a-star-4-5'}).string.strip()
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class': 'a-icon-alt'}).string.strip()
        except:
            rating = ""
    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id': 'acrCustomerReviewText'}).string.strip()
    except AttributeError:
        review_count = ""
    return review_count

# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id': 'availability'})
        available = available.find("span").string.strip()
    except AttributeError:
        available = ""
    return available

# List of Amazon product URLs
product_urls = [
    "https://www.amazon.com/Sony-PlayStation-Pro-1TB-Console-4/dp/B07K14XKZH/",
    "https://www.amazon.com/Xbox-X/dp/B08H75RTZ8/ref=sr_1_1_sspa?crid=17A09AFCHYJ02&keywords=xbox&qid=1698911886&s=videogames&sprefix=xbox%2Cvideogames%2C230&sr=1-1-spons&ufe=app_do%3Aamzn1.fos.c3015c4a-46bb-44b9-81a4-dc28e6d374b3&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1",
    # Add more product URLs here
]

# List to store product information
products = []

if __name__ == '__main__':
    # Headers for request
    HEADERS = ({
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
        'Accept-Language': 'en-US, en;q=0.5'
    })

    for URL in product_urls:
        # HTTP Request
        webpage = requests.get(URL, headers=HEADERS)

        # Soup Object containing all data
        soup = BeautifulSoup(webpage.content, "lxml")

        # Extract product information
        product_info = {
            "Title": get_title(soup),
            "Price": get_price(soup),
            "Rating": get_rating(soup),
            "Review Count": get_review_count(soup),
            "Availability": get_availability(soup)
        }

        products.append(product_info)

# Print the list of product information
for product in products:
    print("Product Title =", product["Title"])
    print("Product Price =", product["Price"])
    print("Product Rating =", product["Rating"])
    print("Number of Product Reviews =", product["Review Count"])
    print("Availability =", product["Availability"])
    print()
    print()
# Out:
# Product Title = Sony PlayStation 4 Pro 1TB Console - Black (PS4 Pro)
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 4,218 ratings
# Availability = Only 1 left in stock - order soon.
#
#
# Product Title = Xbox Series X
# Product Price =
# Product Rating = 4.8 out of 5 stars
# Number of Product Reviews = 23,552 ratings
# Availability = In Stock

# %%
from bs4 import BeautifulSoup
import requests

# Function to extract Product Title
def get_title(soup):
	
	try:
		# Outer Tag Object
		title = soup.find("span", attrs={"id":'productTitle'})

		# Inner NavigatableString Object
		title_value = title.string

		# Title as a string value
		title_string = title_value.strip()

		# # Printing types of values for efficient understanding
		# print(type(title))
		# print(type(title_value))
		# print(type(title_string))
		# print()

	except AttributeError:
		title_string = ""	

	return title_string

# Function to extract Product Price
def get_price(soup):

	try:
		price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()

	except AttributeError:

		try:
			# If there is some deal price
			price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()

		except:		
			price = ""	

	return price

# Function to extract Product Rating
def get_rating(soup):

	try:
		rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
		
	except AttributeError:
		
		try:
			rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
		except:
			rating = ""	

	return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
	try:
		review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()
		
	except AttributeError:
		review_count = ""	

	return review_count

# Function to extract Availability Status
def get_availability(soup):
	try:
		available = soup.find("div", attrs={'id':'availability'})
		available = available.find("span").string.strip()

	except AttributeError:
		available = "Not Available"	

	return available	


if __name__ == '__main__':

	# Headers for request
	HEADERS = ({'User-Agent':
	            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
	            'Accept-Language': 'en-US'})

	# The webpage URL
	URL = "https://www.amazon.com/s?k=playstation+4&ref=nb_sb_noss_2"
	
	# HTTP Request
	webpage = requests.get(URL, headers=HEADERS)

	# Soup Object containing all data
	soup = BeautifulSoup(webpage.content, "lxml")

	# Fetch links as List of Tag Objects
	links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

	# Store the links
	links_list = []

	# Loop for extracting links from Tag Objects
	for link in links:
		links_list.append(link.get('href'))


	# Loop for extracting product details from each link 
	for link in links_list:

		new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

		new_soup = BeautifulSoup(new_webpage.content, "lxml")
		
		# Function calls to display all necessary product information
		print("Product Title =", get_title(new_soup))
		print("Product Price =", get_price(new_soup))
		print("Product Rating =", get_rating(new_soup))
		print("Number of Product Reviews =", get_review_count(new_soup))
		print("Availability =", get_availability(new_soup))
		print()
		print()
# Out:
# Product Title = Sony Playstation PS4 1TB Black Console
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 1,244 ratings
# Availability = In Stock
#
#
# Product Title = PlayStation 4 500GB Console (Renewed)
# Product Price =
# Product Rating = 4.1 out of 5 stars
# Number of Product Reviews = 832 ratings
# Availability = In Stock
#
#
# Product Title = PlayStation 4 Slim 1TB Console - Black (Renewed)
# Product Price =
# Product Rating = 4.3 out of 5 stars
# Number of Product Reviews = 1,421 ratings
# Availability = Only 7 left in stock - order soon.
#
#
# Product Title = Sony PlayStation 4 Slim Limited Edition 1TB Gaming Console
# Product Price =
# Product Rating = 4.3 out of 5 stars
# Number of Product Reviews = 1,279 ratings
# Availability = In Stock
#
#
# Product Title = Sony PlayStation 4 Pro w/ Accessories, 1TB HDD, CUH-7215B - Jet Black (Renewed)
# Product Price =
# Product Rating = 4.1 out of 5 stars
# Number of Product Reviews = 718 ratings
# Availability = In Stock
#
#
# Product Title = PlayStation 4 Slim 500GB Console [Discontinued] (Renewed)
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 1,337 ratings
# Availability = In Stock
#
#
# Product Title = Playstation Sony 4, 500GB Slim System [CUH-2215AB01], Black, 3003347
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 328 ratings
# Availability = In Stock
#
#
# Product Title = Fast & Furious: Spy Racers Rise of SH1FT3R - PlayStation 4
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 408 ratings
# Availability = In Stock
#
#
# Product Title = Uplay Newest Play-Station 4 Console PS.4 with One Wireless Controller, White (Playstation)
# Product Price =
# Product Rating = 4.8 out of 5 stars
# Number of Product Reviews = 8 ratings
# Availability = Only 2 left in stock - order soon.
#
#
# Product Title = Hogwarts Legacy - PlayStation 4 | English | EU Version Region Free
# Product Price =
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 275 ratings
# Availability = In Stock
#
#
# Product Title = Call of Duty: Black Ops 4 (PS4)
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 6,313 ratings
# Availability = In Stock
#
#
# Product Title = KDYGPDCT 2 Pack Wireless Controller for PS4/Pro/PC,Wireless Remote Gamepad with 1000mAh Battery | Double Shock | Audio | 6-Axis Motion Sensor | Share Button (Green + Gray)
# Product Price =
# Product Rating = 5.0 out of 5 stars
# Number of Product Reviews = 1 rating
# Availability = In Stock
#
#
# Product Title = PlayStation4 Console 1TB – Call of Duty Modern Warfare II Bundle (Renewed)
# Product Price =
# Product Rating = 3.5 out of 5 stars
# Number of Product Reviews = 7 ratings
# Availability = Only 2 left in stock - order soon.
#
#
# Product Title = DualShock 4 Wireless Controller for PlayStation 4 - Glacier White
# Product Price =
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 149,799 ratings
# Availability = In Stock
#
#
# Product Title = PS4 Controller Charger Dock Station, 1.8 Hrs Fast Charging PS4 Charging Station, PS4 Charging Station with LED Indicator Charging Chip, Dual USB PS4 Charger Dock for PS4/PS4 Slim/PS4 Pro Charger
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 13,704 ratings
# Availability = In Stock
#
#
# Product Title = LEGO Brawls - PlayStation 4
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 118 ratings
# Availability = In Stock
#
#
# Product Title = LidStyles Vinyl Protection Skin Kit Decal Sticker Compatible with Sony PS4 Original Console (Red Carbon Fiber)
# Product Price =
# Product Rating = 5.0 out of 5 stars
# Number of Product Reviews = 3 ratings
# Availability = Only 10 left in stock - order soon.
#
#
# Product Title = OIVO PS4 Stand Cooling Fan Station for Playstation 4/PS4 Slim/PS4 Pro, PS4 Pro Vertical Stand with Dual Controller EXT Port Charger Dock Station and 12 Game Slots
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 44,130 ratings
# Availability = In Stock
#
#
# Product Title = PlayStation 4 Slim 1TB Console - Black (Renewed)
# Product Price =
# Product Rating = 4.3 out of 5 stars
# Number of Product Reviews = 1,421 ratings
# Availability = Only 7 left in stock - order soon.
#
#
# Product Title = PlayStation 4 Slim 500GB Console [Discontinued] (Renewed)
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 1,337 ratings
# Availability = In Stock
#
#
# Product Title = Sony PlayStation 4 Slim Limited Edition 1TB Gaming Console
# Product Price =
# Product Rating = 4.3 out of 5 stars
# Number of Product Reviews = 1,279 ratings
# Availability = In Stock
#
#
# Product Title = PlayStation 2 Slim Console PS2 (Renewed)
# Product Price =
# Product Rating = 4.0 out of 5 stars
# Number of Product Reviews = 1,113 ratings
# Availability = Only 14 left in stock - order soon.
#
#
# Product Title = PlayStation 4 500GB Console (Renewed)
# Product Price =
# Product Rating = 4.1 out of 5 stars
# Number of Product Reviews = 832 ratings
# Availability = In Stock
#
#
# Product Title = PlayStation 4 Slim 1TB Console - Marvels Spider-Man Bundle (Renewed)
# Product Price =
# Product Rating = 4.3 out of 5 stars
# Number of Product Reviews = 314 ratings
# Availability = Only 4 left in stock - order soon.
#
#
# Product Title = PlayStation 2 Console (Slim Line Version 1) (Renewed)
# Product Price =
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 282 ratings
# Availability = Only 3 left in stock - order soon.
#
#
# Product Title = PlayStation 3 Slim Console 120GB (Old Model) (Renewed)
# Product Price =
# Product Rating = 4.0 out of 5 stars
# Number of Product Reviews = 213 ratings
# Availability = Only 1 left in stock - order soon.
#
#
# Product Title = Fadist Retro Game Console, Built in 900+ Classic Games, 4K HDMI HD Output Video Game Console, Plug and Play Games Console, Ideal Gift for Kids, Adult, Friend, Lover
# Product Price =
# Product Rating = 2.9 out of 5 stars
# Number of Product Reviews = 2 ratings
# Availability = In Stock
#
#
# Product Title = Lies of P - PlayStation 4
# Product Price =
# Product Rating = 5.0 out of 5 stars
# Number of Product Reviews = 14 ratings
# Availability = In Stock
#
#
# Product Title = PlayStation 5 Enhanced Storage 1.8TB Disc Version Console - PS5 Disc Console with 1.8TB Ultra-High Speed PCIe Gen 4 NVNe SSD, DS Controller, Case, White, with GOW Voucher
# Product Price =
# Product Rating = Previous page of related Sponsored Products
# Number of Product Reviews =
# Availability = Only 7 left in stock - order soon.

# %%
from bs4 import BeautifulSoup
import requests

# Function to extract Product Title
def get_title(soup):
	
	try:
		# Outer Tag Object
		title = soup.find("span", attrs={"id":'productTitle'})

		# Inner NavigatableString Object
		title_value = title.string

		# Title as a string value
		title_string = title_value.strip()

		# # Printing types of values for efficient understanding
		# print(type(title))
		# print(type(title_value))
		# print(type(title_string))
		# print()

	except AttributeError:
		title_string = ""	

	return title_string

# Function to extract Product Price
def get_price(soup):

	try:
		price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()

	except AttributeError:

		try:
			# If there is some deal price
			price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()

		except:		
			price = ""	

	return price

# Function to extract Product Rating
def get_rating(soup):

	try:
		rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
		
	except AttributeError:
		
		try:
			rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
		except:
			rating = ""	

	return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
	try:
		review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()
		
	except AttributeError:
		review_count = ""	

	return review_count

# Function to extract Availability Status
def get_availability(soup):
	try:
		available = soup.find("div", attrs={'id':'availability'})
		available = available.find("span").string.strip()

	except AttributeError:
		available = "Not Available"	

	return available	


if __name__ == '__main__':

	# Headers for request
	HEADERS = ({'User-Agent':
	            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
	            'Accept-Language': 'en-US'})

	# The webpage URL
	URL = "https://www.amazon.com/s?k=electronics&crid=2KQPGN95Z37JJ&sprefix=electronic%2Caps%2C155&ref=nb_sb_noss_1"
	
	# HTTP Request
	webpage = requests.get(URL, headers=HEADERS)

	# Soup Object containing all data
	soup = BeautifulSoup(webpage.content, "lxml")

	# Fetch links as List of Tag Objects
	links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

	# Store the links
	links_list = []

	# Loop for extracting links from Tag Objects
	for link in links:
		links_list.append(link.get('href'))


	# Loop for extracting product details from each link 
	for link in links_list:

		new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

		new_soup = BeautifulSoup(new_webpage.content, "lxml")
		
		# Function calls to display all necessary product information
		print("Product Title =", get_title(new_soup))
		print("Product Price =", get_price(new_soup))
		print("Product Rating =", get_rating(new_soup))
		print("Number of Product Reviews =", get_review_count(new_soup))
		print("Availability =", get_availability(new_soup))
		print()
		print()
# Out:
# Product Title = NexiGo Bluetooth Speakerphone, Zoom Certified, 6 Mic Array, 48KHz Audio, Enhanced AI Voice Pickup, Computer Conference Speaker and Microphone for Zoom Teams Webex, Home Office
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 143 ratings
# Availability = In Stock
#
#
# Product Title = ThePhotoStick® Omni 128GB - Secure Photo & Video Backup and Transfer | USB & Multiport Connection | Integrated Software | Portable Memory | External Storage | File Save & Transfer
# Product Price =
# Product Rating = 3.6 out of 5 stars
# Number of Product Reviews = 4,066 ratings
# Availability = In Stock
#
#
# Product Title = Amazon Fire Max 11 tablet, our most powerful tablet yet, vivid 11" display, octa-core processor, 4 GB RAM, 14-hour battery life, 64 GB, Gray
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 3,033 ratings
# Availability = In Stock
#
#
# Product Title = KEOLL Portable Charger 25800mAh Power Bank, 22.5w Fast Charging Battery Pack, LED Display USB C Backup Battery, Slim Portable Phone Charger for iPhone 15/14/13 Pro Samsung Galaxy iPad AirPods
# Product Price =
# Product Rating = 4.8 out of 5 stars
# Number of Product Reviews = 137 ratings
# Availability = In Stock
#
#
# Product Title = Apple AirPods (3rd Generation) Wireless Ear Buds, Bluetooth Headphones, Personalized Spatial Audio, Sweat and Water Resistant, Lightning Charging Case Included, Up to 30 Hours of Battery Life
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 12,003 ratings
# Availability = In Stock
#
#
# Product Title = TOZO Tonal Dots (T12) Wireless Earbuds Bluetooth 5.3 Headphones Built-in ENC Noise Cancelling Mic, 55 Hrs Playtime App Customize EQ IPX8 Waterproof LED Digital Display Premium Sound Headset Black
# Product Price =
# Product Rating = 4.3 out of 5 stars
# Number of Product Reviews = 72,592 ratings
# Availability = In Stock
#
#
# Product Title = SmallRig V Mount Battery VB99, 6700mAh 99Wh 14.8V mini V-Mount Battery Support 65W PD USB-C Fast Charger, with D-TAP, USB-A, Dual DC Port, OLED Screen, for Camera, Camcorder, Monitor, Filmmaker - 3580
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 140 ratings
# Availability = In Stock
#
#
# Product Title = TOZO T20 Wireless Earbuds Bluetooth Headphones 48.5 Hrs Playtime with LED Digital Display, IPX8 Waterproof, Dual Mic Call Noise Cancelling 10mm Broad Range Speakers with Wireless Charging Case Black
# Product Price =
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 750 ratings
# Availability = In Stock
#
#
# Product Title = Yealink UH38 Bluetooth USB Wired Headset with Microphone Stereo for PC Computer Headset Telephone Headset Teams Certified with Noise-Canceling with 360° Busylight
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 466 ratings
# Availability =
#
#
# Product Title = UMIDIGI G1 Tab Android 13 Tablet 2023, 8（4+4） GB+64GB 1TB Expand, Wi-Fi 6 Model, 10.1 inch Tablet with Quad-Core Processor up to 2.0 GHz, 6000mAh, Dual Camera, BT, 1280 * 800 FHD IPS Touch Screen
# Product Price =
# Product Rating = 4.3 out of 5 stars
# Number of Product Reviews = 262 ratings
# Availability = In Stock
#
#
# Product Title = Apple AirPods (2nd Generation) Wireless Ear Buds, Bluetooth Headphones with Lightning Charging Case Included, Over 24 Hours of Battery Life, Effortless Setup for iPhone
# Product Price =
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 596,101 ratings
# Availability = In Stock
#
#
# Product Title = Denon Receiver DRA-900H - 2-Channel Stereo Network Receiver (2023 Model) - 100W/Ch. Hi-Fi Amplification, Built-in HEOS, HDCP 2.3 Processing with ARC/eARC Support, Dolby Vision, HLG, Dynamic HDR
# Product Price =
# Product Rating = 4.3 out of 5 stars
# Number of Product Reviews = 420 ratings
# Availability = Only 8 left in stock - order soon.
#
#
# Product Title = Nintendo Switch™ with Neon Blue and Neon Red Joy‑Con™
# Product Price =
# Product Rating = 4.8 out of 5 stars
# Number of Product Reviews = 4,966 ratings
# Availability = In Stock
#
#
# Product Title = JBL Go 3 Eco: Portable Speaker with Bluetooth, Built-in Battery, Waterproof and Dustproof Feature - Blue
# Product Price =
# Product Rating = 4.8 out of 5 stars
# Number of Product Reviews = 31,816 ratings
# Availability = In Stock
#
#
# Product Title = samtechT Smart Lock, Keyless Entry Door Lock, Fingerprint Door Lock, Smart Door Lock with Handle, Digital Door Lock, Smart Lock for Front Door, Bluetooth Electronic Door Lock (Powered by Sifely)
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 2,328 ratings
# Availability = In Stock
#
#
# Product Title = Electronic Accessories Case, Universal Cable Cord Holder Organizer/Electronic Case, Waterproof Portable Cable Organizer Bag, USB Flash Drives Bag, Cable case Bag, USB Case Organizer,USB Charger Bag
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 4,624 ratings
# Availability = In Stock
#
#
# Product Title = Celestron – StarSense Explorer 114mm Tabletop Dobsonian Smartphone App-Enabled Telescope – Works with StarSense App to Help You Find Nebulae, Planets & More – iPhone/Android Compatible
# Product Price =
# Product Rating = 5.0 out of 5 stars
# Number of Product Reviews = 1 rating
# Availability = Only 14 left in stock (more on the way).
#
#
# Product Title = Apple AirPods Pro (2nd Generation) Wireless Ear Buds with USB-C Charging, Up to 2X More Active Noise Cancelling Bluetooth Headphones, Transparency Mode, Adaptive Audio, Personalized Spatial Audio
# Product Price =
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 986 ratings
# Availability = In Stock
#
#
# Product Title = Amazon Fire 7 tablet, 7” display, read and watch, under $60 with 10-hour battery life, (2022 release), 16 GB, Black
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 12,087 ratings
# Availability = In Stock
#
#
# Product Title = Meta Quest 3 128GB— Breakthrough Mixed Reality — Powerful Performance — Asgard’s Wrath 2 Bundle
# Product Price =
# Product Rating = 4.0 out of 5 stars
# Number of Product Reviews = 477 ratings
# Availability = In Stock
#
#
# Product Title = Energizer Lithium Coin Blister Pack Watch/Electronic Batteries
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 178 ratings
# Availability = In Stock
#
#
# Product Title = Meta Quest 3 128GB— Breakthrough Mixed Reality — Powerful Performance — Asgard’s Wrath 2 Bundle
# Product Price =
# Product Rating = 4.0 out of 5 stars
# Number of Product Reviews = 477 ratings
# Availability = In Stock
#
#
# Product Title = Surge Protector, Multi Plug Outlet Extender with Night Light for Home, Office, School, Addtam 5-Outlet Splitter and 4 USB Ports(1 USB C), Wall Charger Power Strip, ETL Listed
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 6,581 ratings
# Availability = In Stock
#
#
# Product Title = Mitesbony iPhone Fast Charger 10 FT [Apple MFi Certified] 2 Pack PD 20W USB C Charger Block with 10FT Long Type C Lightning Cable for iPhone 14 13 12 11 XS XR X 8 iPad,White
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 2,755 ratings
# Availability = In Stock
#
#
# Product Title = Flat Extension Cord, 5 Ft Ultra Thin Flat Plug Power Strip Surge Protector, 8 Widely Outlet Extender 4 USB Ports(2USB C),1080J Multi Plug Outlet Wall Mount for Home Office Dorm Room Travel Essentials
# Product Price =
# Product Rating = 4.8 out of 5 stars
# Number of Product Reviews = 3,122 ratings
# Availability = In Stock
#
#
# Product Title = Nekteck Shiatsu Foot Massager Machine with Soothing Heat, Deep Kneading Therapy, Air Compression, Improve Blood Circulation and Foot Wellness,Relax for Home or Office Use(Gray)
# Product Price =
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 17,970 ratings
# Availability = In Stock
#
#
# Product Title = MEEZAA Telescope, 150EQ Reflector Telescope for Adults Astronomy Beginners, Manual Equatorial Professional Telescopes Astronomy with 2X Barlow Lens, Phone Adapter, Adjustable Tripod and Moon Filter
# Product Price =
# Product Rating = 5.0 out of 5 stars
# Number of Product Reviews = 3 ratings
# Availability = In Stock
